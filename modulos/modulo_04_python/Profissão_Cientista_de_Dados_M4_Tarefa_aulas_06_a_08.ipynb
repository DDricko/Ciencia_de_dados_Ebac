# %% [markdown]
# <a href="https://colab.research.google.com/github/DDricko/Ciencia_de_dados_Ebac/blob/main/Profiss%C3%A3o_Cientista_de_Dados_M4_Tarefa_aulas_06_a_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui

import pandas as pd
import requests

# %%
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
r = requests.get(url)
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df.head()
# Out:
#    id_pleito tipo_interessado            interessado  cod_ibge  uf num_pvl  \
# 0       9931        Município      Soledade de Minas   3167806  MG    None
# 1       9934        Município                Itupeva   3524006  SP    None
# 2       9947        Município  São José do Rio Preto   3549805  SP    None
# 3      10323        Município          Montes Claros   3143302  MG    None
# 4      10339        Município          Carvalhópolis   3114709  MG    None
#
#                            status          num_processo        data_protocolo  \
# 0  Arquivado por decurso de prazo  17944.001082/2010-32  2010-11-04T00:00:00Z
# 1                        Deferido  17944.001083/2006-09  2006-07-06T00:00:00Z
# 2                        Deferido  17944.001085/2007-71  2007-07-03T00:00:00Z
# 3                        Deferido  17944.001171/2007-83  2007-09-18T00:00:00Z
# 4                        Deferido  17944.001175/2011-48  2011-08-25T00:00:00Z
#
# ...

# %%
df_rj = df[df['uf'] == 'RJ']
df_rj
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 32        11690        Município          Tanguá   3305752  RJ
# 71        13579        Município  Rio de Janeiro   3304557  RJ
# 214        9109        Município     Barra Mansa   3300407  RJ
# 234       10412        Município          Maricá   3302700  RJ
# 250        9234        Município   Nova Friburgo   3303401  RJ
# ...         ...              ...             ...       ...  ..
# 4814      27100        Município  Rio de Janeiro   3304557  RJ
# 4835      12078        Município         Resende   3304201  RJ
# 4873       5689        Município       Rio Claro   3304409  RJ
# 4893       9308        Município     Nova Iguaçu   3303500  RJ
# 4958      22824        Município  Rio de Janeiro   3304557  RJ
#
#                    num_pvl                          status  \
# 32                    None                       Arquivado
# 71                    None                       Arquivado
# ...

# %%
from os import stat
# 2) Seu código aqui
status_freq = df_rj['status'].value_counts()
top3_status = status_freq.head(3)
top3_status
# Out:
# status
# Deferido                                                 26
# Arquivado                                                11
# Encaminhado à PGFN com manifestação técnica favorável     8
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df_rj['data_status'] = df_rj['data_status'].astype(str)

df_valid = df_rj[df_rj['data_status'].str.match(r'\d{2}/\d{2}/\d{4}')]

df_valid['ano_status'] = df_valid['data_status'].str[-4:]

ano_freq = df_valid['ano_status'].value_counts()
print(ano_freq)
# Out:
# ano_status
# 2008    9
# 2011    7
# 2023    6
# 2007    5
# 2025    5
# 2013    5
# 2012    5
# 2009    4
# 2020    4
# 2019    4
# 2016    3
# 2015    2
# 2010    2
# 2021    2
# 2002    1
# 2006    1
# 2018    1
# 2024    1
# 2022    1
# 2014    1
# Name: count, dtype: int64
# /tmp/ipython-input-324130865.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rj['data_status'] = df_rj['data_status'].astype(str)

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
def consultar_pvl(uf, interessado):
    """
    Consulta a API de PVL do Tesouro e retorna os dados como DataFrame.

    Parâmetros:
        uf (str): UF a ser consultada, ex: 'MG', 'BA'
        interessado (str): 'Estado' ou 'Município'

    Retorno:
        pd.DataFrame: Dados da consulta
    """
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

    # Montando os parâmetros de filtro
    params = {
        'uf': uf,
        'tipo_interessado': interessado
    }

    # Requisição GET
    response = requests.get(url, params=params)
    data = response.json()

    # Transformar em DataFrame
    df = pd.DataFrame(data['items'])

    return df

# %%
df_mg_estado = consultar_pvl('MG', 'Estado')
df_mg_estado.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0      11328           Estado  Minas Gerais        31  MG
# 1      13618           Estado  Minas Gerais        31  MG
# 2      10338           Estado  Minas Gerais        31  MG
# 3      20534           Estado  Minas Gerais        31  MG
# 4      11054           Estado  Minas Gerais        31  MG
#
#                 num_pvl                                             status  \
# 0                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3  00000.000000/2017-69                     Arquivado por decurso de prazo
# 4                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#            num_processo        data_protocolo  \
# 0  17944.001412/2012-51  2012-12-11T00:00:00Z
# 1  19405.000037/2006-15  2009-02-26T00:00:00Z
# ...

# %%
# 2) Seu código aqui
df_mg_estado = consultar_pvl('MG', 'Estado')
freq_arquivado = df_mg_estado[df_mg_estado['status'] == 'Arquivado por decurso de prazo'].shape[0]

print(f"Solicitações: Arquivado por decurso de prazo em MG (Estado): {freq_arquivado}")
# Out:
# Solicitações: Arquivado por decurso de prazo em MG (Estado): 1

# %%
# 3) Seu código aqui
df_ba_municipio = consultar_pvl('BA', 'Município')

# Filtrar status deferido
df_ba_deferido = df_ba_municipio[df_ba_municipio['status'] == 'Deferido']

# Contar por município
municipio_top = df_ba_deferido['interessado'].value_counts().idxmax()
qtd_top = df_ba_deferido['interessado'].value_counts().max()

print(f"Município da Bahia com mais solicitações deferidas: {municipio_top} ({qtd_top} solicitações)")
# Out:
# Município da Bahia com mais solicitações deferidas: Luís Eduardo Magalhães (16 solicitações)

# %%
# 4) Seu código aqui
